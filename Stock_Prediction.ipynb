# %% [markdown]
# **OBJECTIVE OF THE ANALYSIS :**
#
# **TO** PREDICT THE STOCK PRICE OF A COMPANY USING LSTM.

# %% [markdown]
# **ABOUT DATASET :**
#
# Google Stock Prediction
# This dataset contains historical data of Google's stock prices and related attributes. It consists of 14 columns and a smaller subset of 1257 rows. Each column represents a specific attribute, and each row contains the corresponding values for that attribute.
#
# The columns in the dataset are as follows:
#
# Symbol: The name of the company, which is GOOG in this case.
# Date: The year and date of the stock data.
# Close: The closing price of Google's stock on a particular day.
# High: The highest value reached by Google's stock on the given day.
# Low: The lowest value reached by Google's stock on the given day.
# Open: The opening value of Google's stock on the given day.
# Volume: The trading volume of Google's stock on the given day, i.e., the number of shares traded.
# adjClose: The adjusted closing price of Google's stock, considering factors such as dividends and stock splits.
# adjHigh: The adjusted highest value reached by Google's stock on the given day.
# adjLow: The adjusted lowest value reached by Google's stock on the given day.
# adjOpen: The adjusted opening value of Google's stock on the given day.
# adjVolume: The adjusted trading volume of Google's stock on the given day, accounting for factors such as stock splits.
# divCash: The amount of cash dividend paid out to shareholders on the given day.
# splitFactor: The split factor, if any, applied to Google's stock on the given day. A split factor of 1 indicates no split.

# %% [markdown]
# **STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Google Stocks.csv')
df.head(10)
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# **STEP 2 : GATHERING INSIGHTS**

# %%
print("Shape of data:",df.shape)
# Out:
# Shape of data: (1258, 14)

# %%
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   symbol       1258 non-null   object
#  1   date         1258 non-null   object
#  2   close        1258 non-null   float64
#  3   high         1258 non-null   float64
#  4   low          1258 non-null   float64
#  5   open         1258 non-null   float64
#  6   volume       1258 non-null   int64
#  7   adjClose     1258 non-null   float64
#  8   adjHigh      1258 non-null   float64
#  9   adjLow       1258 non-null   float64
#  10  adjOpen      1258 non-null   float64
#  11  adjVolume    1258 non-null   int64
#  12  divCash      1258 non-null   float64
#  13  splitFactor  1258 non-null   float64
# dtypes: float64(10), int64(2), object(2)
# memory usage: 137.7+ KB

# %%
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# **STEP 3 : DATA PRE-PROCESSING**

# %%
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data)
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# **STEP 4 : CREATING LSTM MODEL**

# %%
model = Sequential()
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1))
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 50, 50)            10600
#
#  dropout (Dropout)           (None, 50, 50)            0
#
#  lstm_1 (LSTM)               (None, 50)                20200
#
#  dense (Dense)               (None, 2)                 102
#
# =================================================================
# Total params: 30902 (120.71 KB)
# Trainable params: 30902 (120.71 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 [==============================] - 7s 91ms/step - loss: 0.0101 - mean_absolute_error: 0.0699 - val_loss: 0.0274 - val_mean_absolute_error: 0.1447
# Epoch 2/100
# 28/28 [==============================] - 2s 76ms/step - loss: 7.9314e-04 - mean_absolute_error: 0.0225 - val_loss: 0.0073 - val_mean_absolute_error: 0.0686
# Epoch 3/100
# 28/28 [==============================] - 2s 71ms/step - loss: 4.4059e-04 - mean_absolute_error: 0.0157 - val_loss: 0.0038 - val_mean_absolute_error: 0.0475
# Epoch 4/100
# 28/28 [==============================] - 1s 48ms/step - loss: 4.2085e-04 - mean_absolute_error: 0.0149 - val_loss: 0.0027 - val_mean_absolute_error: 0.0390
# Epoch 5/100
# 28/28 [==============================] - 1s 50ms/step - loss: 4.2915e-04 - mean_absolute_error: 0.0150 - val_loss: 0.0051 - val_mean_absolute_error: 0.0570
# Epoch 6/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.7721e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0048 - val_mean_absolute_error: 0.0552
# Epoch 7/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.8602e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0043 - val_mean_absolute_error: 0.0510
# Epoch 8/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.7645e-04 - mean_absolute_error: 0.0141 - val_loss: 0.0030 - val_mean_absolute_error: 0.0410
# Epoch 9/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.7890e-04 - mean_absolute_error: 0.0142 - val_loss: 0.0039 - val_mean_absolute_error: 0.0484
# Epoch 10/100
# 28/28 [==============================] - 2s 71ms/step - loss: 3.6834e-04 - mean_absolute_error: 0.0140 - val_loss: 0.0045 - val_mean_absolute_error: 0.0533
# Epoch 11/100
# 28/28 [==============================] - 2s 80ms/step - loss: 3.7623e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0051 - val_mean_absolute_error: 0.0583
# Epoch 12/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.5766e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0039 - val_mean_absolute_error: 0.0489
# Epoch 13/100
# 28/28 [==============================] - 1s 48ms/step - loss: 3.4457e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0048 - val_mean_absolute_error: 0.0561
# Epoch 14/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.4141e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0039 - val_mean_absolute_error: 0.0491
# Epoch 15/100
# 28/28 [==============================] - 1s 49ms/step - loss: 3.7288e-04 - mean_absolute_error: 0.0143 - val_loss: 0.0024 - val_mean_absolute_error: 0.0370
# Epoch 16/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.3758e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0028 - val_mean_absolute_error: 0.0407
# Epoch 17/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.0983e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0040 - val_mean_absolute_error: 0.0505
# Epoch 18/100
# 28/28 [==============================] - 2s 58ms/step - loss: 3.1668e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0056 - val_mean_absolute_error: 0.0616
# Epoch 19/100
# 28/28 [==============================] - 2s 83ms/step - loss: 3.3915e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
# Epoch 20/100
# 28/28 [==============================] - 1s 50ms/step - loss: 3.4586e-04 - mean_absolute_error: 0.0136 - val_loss: 0.0040 - val_mean_absolute_error: 0.0502
# Epoch 21/100
# 28/28 [==============================] - 1s 48ms/step - loss: 3.3585e-04 - mean_absolute_error: 0.0134 - val_loss: 0.0044 - val_mean_absolute_error: 0.0539
# Epoch 22/100
# 28/28 [==============================] - 1s 51ms/step - loss: 3.0548e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0027 - val_mean_absolute_error: 0.0395
# Epoch 23/100
# 28/28 [==============================] - 1s 50ms/step - loss: 2.9560e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0019 - val_mean_absolute_error: 0.0327
# Epoch 24/100
# 28/28 [==============================] - 2s 73ms/step - loss: 3.3008e-04 - mean_absolute_error: 0.0133 - val_loss: 0.0022 - val_mean_absolute_error: 0.0352
# Epoch 25/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.9994e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0048 - val_mean_absolute_error: 0.0568
# Epoch 26/100
# 28/28 [==============================] - 2s 83ms/step - loss: 2.7337e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0026 - val_mean_absolute_error: 0.0386
# Epoch 27/100
# 28/28 [==============================] - 3s 94ms/step - loss: 3.0427e-04 - mean_absolute_error: 0.0130 - val_loss: 0.0025 - val_mean_absolute_error: 0.0380
# Epoch 28/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.5819e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0043 - val_mean_absolute_error: 0.0531
# Epoch 29/100
# 28/28 [==============================] - 2s 63ms/step - loss: 2.5217e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0043 - val_mean_absolute_error: 0.0521
# Epoch 30/100
# 28/28 [==============================] - 2s 59ms/step - loss: 2.6889e-04 - mean_absolute_error: 0.0121 - val_loss: 0.0030 - val_mean_absolute_error: 0.0416
# Epoch 31/100
# 28/28 [==============================] - 2s 78ms/step - loss: 2.5430e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0042 - val_mean_absolute_error: 0.0517
# Epoch 32/100
# 28/28 [==============================] - 2s 70ms/step - loss: 2.5972e-04 - mean_absolute_error: 0.0117 - val_loss: 0.0030 - val_mean_absolute_error: 0.0412
# Epoch 33/100
# 28/28 [==============================] - 2s 89ms/step - loss: 2.5908e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0053 - val_mean_absolute_error: 0.0589
# Epoch 34/100
# 28/28 [==============================] - 2s 56ms/step - loss: 2.3459e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0028 - val_mean_absolute_error: 0.0412
# Epoch 35/100
# 28/28 [==============================] - 2s 54ms/step - loss: 2.6073e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0051 - val_mean_absolute_error: 0.0576
# Epoch 36/100
# 28/28 [==============================] - 2s 55ms/step - loss: 2.5379e-04 - mean_absolute_error: 0.0120 - val_loss: 0.0049 - val_mean_absolute_error: 0.0571
# Epoch 37/100
# 28/28 [==============================] - 2s 58ms/step - loss: 2.5536e-04 - mean_absolute_error: 0.0116 - val_loss: 0.0037 - val_mean_absolute_error: 0.0478
# Epoch 38/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.3245e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0024 - val_mean_absolute_error: 0.0369
# Epoch 39/100
# 28/28 [==============================] - 1s 53ms/step - loss: 2.3405e-04 - mean_absolute_error: 0.0112 - val_loss: 0.0054 - val_mean_absolute_error: 0.0615
# Epoch 40/100
# 28/28 [==============================] - 2s 87ms/step - loss: 2.4270e-04 - mean_absolute_error: 0.0114 - val_loss: 0.0031 - val_mean_absolute_error: 0.0433
# Epoch 41/100
# 28/28 [==============================] - 2s 64ms/step - loss: 2.2432e-04 - mean_absolute_error: 0.0109 - val_loss: 0.0033 - val_mean_absolute_error: 0.0443
# Epoch 42/100
# 28/28 [==============================] - 2s 62ms/step - loss: 2.0562e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0022 - val_mean_absolute_error: 0.0333
# Epoch 43/100
# 28/28 [==============================] - 1s 51ms/step - loss: 2.1567e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0035 - val_mean_absolute_error: 0.0463
# Epoch 44/100
# 28/28 [==============================] - 2s 57ms/step - loss: 2.1377e-04 - mean_absolute_error: 0.0108 - val_loss: 0.0013 - val_mean_absolute_error: 0.0258
# Epoch 45/100
# 28/28 [==============================] - 1s 49ms/step - loss: 2.4230e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0027 - val_mean_absolute_error: 0.0405
# Epoch 46/100
# 28/28 [==============================] - 1s 49ms/step - loss: 2.0026e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0025 - val_mean_absolute_error: 0.0392
# Epoch 47/100
# 28/28 [==============================] - 1s 50ms/step - loss: 2.0845e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 48/100
# 28/28 [==============================] - 2s 79ms/step - loss: 2.0236e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0028 - val_mean_absolute_error: 0.0410
# Epoch 49/100
# 28/28 [==============================] - 2s 61ms/step - loss: 2.0677e-04 - mean_absolute_error: 0.0105 - val_loss: 0.0019 - val_mean_absolute_error: 0.0324
# Epoch 50/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.9775e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0017 - val_mean_absolute_error: 0.0310
# Epoch 51/100
# 28/28 [==============================] - 2s 63ms/step - loss: 1.9669e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0023 - val_mean_absolute_error: 0.0362
# Epoch 52/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.8917e-04 - mean_absolute_error: 0.0098 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 53/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.9361e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0021 - val_mean_absolute_error: 0.0349
# Epoch 54/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.8731e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0024 - val_mean_absolute_error: 0.0377
# Epoch 55/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.8939e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0031 - val_mean_absolute_error: 0.0437
# Epoch 56/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.8361e-04 - mean_absolute_error: 0.0096 - val_loss: 0.0022 - val_mean_absolute_error: 0.0356
# Epoch 57/100
# 28/28 [==============================] - 2s 65ms/step - loss: 1.9276e-04 - mean_absolute_error: 0.0101 - val_loss: 0.0016 - val_mean_absolute_error: 0.0293
# Epoch 58/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.8736e-04 - mean_absolute_error: 0.0099 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329
# Epoch 59/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.6966e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0014 - val_mean_absolute_error: 0.0282
# Epoch 60/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.7096e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0010 - val_mean_absolute_error: 0.0233
# Epoch 61/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.6925e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0013 - val_mean_absolute_error: 0.0266
# Epoch 62/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.6828e-04 - mean_absolute_error: 0.0094 - val_loss: 0.0016 - val_mean_absolute_error: 0.0292
# Epoch 63/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.6230e-04 - mean_absolute_error: 0.0091 - val_loss: 0.0026 - val_mean_absolute_error: 0.0403
# Epoch 64/100
# 28/28 [==============================] - 2s 90ms/step - loss: 1.5728e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0012 - val_mean_absolute_error: 0.0256
# Epoch 65/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.5330e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0016 - val_mean_absolute_error: 0.0303
# Epoch 66/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.6034e-04 - mean_absolute_error: 0.0093 - val_loss: 0.0026 - val_mean_absolute_error: 0.0403
# Epoch 67/100
# 28/28 [==============================] - 1s 54ms/step - loss: 1.7773e-04 - mean_absolute_error: 0.0095 - val_loss: 9.3912e-04 - val_mean_absolute_error: 0.0224
# Epoch 68/100
# 28/28 [==============================] - 2s 60ms/step - loss: 1.7131e-04 - mean_absolute_error: 0.0095 - val_loss: 0.0014 - val_mean_absolute_error: 0.0279
# Epoch 69/100
# 28/28 [==============================] - 2s 58ms/step - loss: 1.4613e-04 - mean_absolute_error: 0.0087 - val_loss: 0.0013 - val_mean_absolute_error: 0.0273
# Epoch 70/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.4683e-04 - mean_absolute_error: 0.0087 - val_loss: 8.8277e-04 - val_mean_absolute_error: 0.0218
# Epoch 71/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.5024e-04 - mean_absolute_error: 0.0088 - val_loss: 8.0404e-04 - val_mean_absolute_error: 0.0206
# Epoch 72/100
# 28/28 [==============================] - 2s 89ms/step - loss: 1.5213e-04 - mean_absolute_error: 0.0089 - val_loss: 0.0012 - val_mean_absolute_error: 0.0254
# Epoch 73/100
# 28/28 [==============================] - 3s 91ms/step - loss: 1.4602e-04 - mean_absolute_error: 0.0086 - val_loss: 0.0016 - val_mean_absolute_error: 0.0322
# Epoch 74/100
# 28/28 [==============================] - 2s 54ms/step - loss: 1.3545e-04 - mean_absolute_error: 0.0084 - val_loss: 9.8294e-04 - val_mean_absolute_error: 0.0232
# Epoch 75/100
# 28/28 [==============================] - 2s 59ms/step - loss: 1.3585e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0017 - val_mean_absolute_error: 0.0319
# Epoch 76/100
# 28/28 [==============================] - 2s 55ms/step - loss: 1.3575e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0014 - val_mean_absolute_error: 0.0288
# Epoch 77/100
# 28/28 [==============================] - 1s 53ms/step - loss: 1.4575e-04 - mean_absolute_error: 0.0084 - val_loss: 0.0013 - val_mean_absolute_error: 0.0272
# Epoch 78/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.2713e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0019 - val_mean_absolute_error: 0.0348
# Epoch 79/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.3964e-04 - mean_absolute_error: 0.0083 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 80/100
# 28/28 [==============================] - 2s 77ms/step - loss: 1.4591e-04 - mean_absolute_error: 0.0089 - val_loss: 9.9514e-04 - val_mean_absolute_error: 0.0229
# Epoch 81/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.3366e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0024 - val_mean_absolute_error: 0.0395
# Epoch 82/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.2605e-04 - mean_absolute_error: 0.0081 - val_loss: 0.0021 - val_mean_absolute_error: 0.0368
# Epoch 83/100
# 28/28 [==============================] - 2s 57ms/step - loss: 1.4224e-04 - mean_absolute_error: 0.0085 - val_loss: 0.0019 - val_mean_absolute_error: 0.0364
# Epoch 84/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.3059e-04 - mean_absolute_error: 0.0083 - val_loss: 6.2681e-04 - val_mean_absolute_error: 0.0187
# Epoch 85/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.1876e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0255
# Epoch 86/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.3003e-04 - mean_absolute_error: 0.0082 - val_loss: 0.0018 - val_mean_absolute_error: 0.0328
# Epoch 87/100
# 28/28 [==============================] - 2s 66ms/step - loss: 1.2883e-04 - mean_absolute_error: 0.0081 - val_loss: 6.8673e-04 - val_mean_absolute_error: 0.0192
# Epoch 88/100
# 28/28 [==============================] - 2s 76ms/step - loss: 1.1026e-04 - mean_absolute_error: 0.0076 - val_loss: 6.9048e-04 - val_mean_absolute_error: 0.0193
# Epoch 89/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.2790e-04 - mean_absolute_error: 0.0082 - val_loss: 3.8057e-04 - val_mean_absolute_error: 0.0149
# Epoch 90/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.4620e-04 - mean_absolute_error: 0.0088 - val_loss: 0.0011 - val_mean_absolute_error: 0.0248
# Epoch 91/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.2488e-04 - mean_absolute_error: 0.0079 - val_loss: 7.7428e-04 - val_mean_absolute_error: 0.0202
# Epoch 92/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.1043e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256
# Epoch 93/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.1136e-04 - mean_absolute_error: 0.0075 - val_loss: 5.5424e-04 - val_mean_absolute_error: 0.0172
# Epoch 94/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.2314e-04 - mean_absolute_error: 0.0078 - val_loss: 0.0019 - val_mean_absolute_error: 0.0353
# Epoch 95/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.2200e-04 - mean_absolute_error: 0.0080 - val_loss: 0.0014 - val_mean_absolute_error: 0.0295
# Epoch 96/100
# 28/28 [==============================] - 3s 93ms/step - loss: 1.1228e-04 - mean_absolute_error: 0.0076 - val_loss: 9.9397e-04 - val_mean_absolute_error: 0.0238
# Epoch 97/100
# 28/28 [==============================] - 1s 49ms/step - loss: 1.0255e-04 - mean_absolute_error: 0.0073 - val_loss: 0.0015 - val_mean_absolute_error: 0.0312
# Epoch 98/100
# 28/28 [==============================] - 1s 50ms/step - loss: 1.1943e-04 - mean_absolute_error: 0.0078 - val_loss: 9.2999e-04 - val_mean_absolute_error: 0.0224
# Epoch 99/100
# 28/28 [==============================] - 1s 48ms/step - loss: 1.0821e-04 - mean_absolute_error: 0.0073 - val_loss: 8.7405e-04 - val_mean_absolute_error: 0.0209
# Epoch 100/100
# 28/28 [==============================] - 1s 51ms/step - loss: 1.1677e-04 - mean_absolute_error: 0.0077 - val_loss: 0.0013 - val_mean_absolute_error: 0.0276

# %%
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 [==============================] - 2s 12ms/step
# array([[0.402091  , 0.4037986 ],
#        [0.4012564 , 0.402409  ],
#        [0.39563194, 0.39644656],
#        [0.39955547, 0.40113863],
#        [0.40318388, 0.4051102 ]], dtype=float32)

# %%
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1416.4445, 1416.6361],
#        [1414.8972, 1414.0607],
#        [1404.47  , 1403.0103],
#        [1411.7439, 1411.7063],
#        [1418.4707, 1419.0669]], dtype=float32)

# %% [markdown]
# **STEP 5 : VISUALIZING ACTUAL VS PREDICTED DATA**
#
# ---

# %%
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1416.444458      1416.636108
# 2020-05-28  1396.86  1416.73     1414.897217      1414.060669
# 2020-05-29  1416.94  1428.92     1404.469971      1403.010254
# 2020-06-01  1418.39  1431.82     1411.743896      1411.706299
# 2020-06-02  1430.55  1439.22     1418.470703      1419.066895

# %%
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# **STEP 6. PREDICTING UPCOMING 10 DAYS**

# %%
df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
#                open    close  open_predicted  close_predicted
# 2021-06-09  2499.50  2491.40     2383.652344      2340.303467
# 2021-06-10  2494.01  2521.60     2394.217773      2347.812256
# 2021-06-11  2524.92  2513.93     2405.093750      2357.308594
# 2021-06-12      NaN      NaN             NaN              NaN
# 2021-06-13      NaN      NaN             NaN              NaN
# 2021-06-14      NaN      NaN             NaN              NaN
# 2021-06-15      NaN      NaN             NaN              NaN
# 2021-06-16      NaN      NaN             NaN              NaN

# %%
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 131ms/step
# 1/1 [==============================] - 0s 100ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 33ms/step

# %%
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()
